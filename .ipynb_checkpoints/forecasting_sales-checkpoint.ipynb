# %%
import pandas as pd 
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.model_selection import train_test_split
import numpy as np

train = pd.read_csv('E:/personal_projects/competitive-data-science-predict-future-sales/sales_train.csv')

test = pd.read_csv('E:/personal_projects/competitive-data-science-predict-future-sales/test.csv')
items = pd.read_csv('E:/personal_projects/competitive-data-science-predict-future-sales/items.csv')
categories = pd.read_csv('E:/personal_projects/competitive-data-science-predict-future-sales/item_categories.csv')
shops = pd.read_csv('E:/personal_projects/competitive-data-science-predict-future-sales/shops.csv')

# %%
test.shape
# Out:
# (214200, 3)

# %%
import datetime , nltk

# %%
train['date'] = pd.to_datetime(train['date'], format = "%d.%m.%Y")

# %%
train['year'] = train['date'].dt.year

# %%
train['month'] = train['date'].dt.month

# %%
train
# Out:
#               date  date_block_num  shop_id  item_id  item_price  \
# 0       2013-01-02               0       59    22154      999.00
# 1       2013-01-03               0       25     2552      899.00
# 2       2013-01-05               0       25     2552      899.00
# 3       2013-01-06               0       25     2554     1709.05
# 4       2013-01-15               0       25     2555     1099.00
# ...            ...             ...      ...      ...         ...
# 2935844 2015-10-10              33       25     7409      299.00
# 2935845 2015-10-09              33       25     7460      299.00
# 2935846 2015-10-14              33       25     7459      349.00
# 2935847 2015-10-22              33       25     7440      299.00
# 2935848 2015-10-03              33       25     7460      299.00
#
#          item_cnt_day  year  month
# 0                 1.0  2013      1
# 1                 1.0  2013      1
# 2                -1.0  2013      1
# 3                 1.0  2013      1
# 4                 1.0  2013      1
# ...               ...   ...    ...
# 2935844           1.0  2015     10
# 2935845           1.0  2015     10
# 2935846           1.0  2015     10
# 2935847           1.0  2015     10
# 2935848           1.0  2015     10
#
# [2935849 rows x 8 columns]

# %%
shops
# Out:
#                                           shop_name  shop_id
# 0                     !Якутск Орджоникидзе, 56 фран        0
# 1                     !Якутск ТЦ "Центральный" фран        1
# 2                                  Адыгея ТЦ "Мега"        2
# 3                    Балашиха ТРК "Октябрь-Киномир"        3
# 4                          Волжский ТЦ "Волга Молл"        4
# 5                            Вологда ТРЦ "Мармелад"        5
# 6                        Воронеж (Плехановская, 13)        6
# 7                            Воронеж ТРЦ "Максимир"        7
# 8                      Воронеж ТРЦ Сити-Парк "Град"        8
# 9                                 Выездная Торговля        9
# 10                       Жуковский ул. Чкалова 39м?       10
# 11                       Жуковский ул. Чкалова 39м²       11
# 12                              Интернет-магазин ЧС       12
# 13                              Казань ТЦ "Бехетле"       13
# 14                          Казань ТЦ "ПаркХаус" II       14
# 15                             Калуга ТРЦ "XXI век"       15
# 16                                 Коломна ТЦ "Рио"       16
# 17                    Красноярск ТЦ "Взлетка Плаза"       17
# 18                             Красноярск ТЦ "Июнь"       18
# 19                            Курск ТЦ "Пушкинский"       19
# 20                              Москва "Распродажа"       20
# 21                           Москва МТРЦ "Афи Молл"       21
# 22                               Москва Магазин С21       22
# 23                 Москва ТК "Буденовский" (пав.А2)       23
# 24                 Москва ТК "Буденовский" (пав.К7)       24
# 25                              Москва ТРК "Атриум"       25
# 26                      Москва ТЦ "Ареал" (Беляево)       26
# 27                   Москва ТЦ "МЕГА Белая Дача II"       27
# 28                  Москва ТЦ "МЕГА Теплый Стан" II       28
# 29               Москва ТЦ "Новый век" (Новокосино)       29
# 30                           Москва ТЦ "Перловский"       30
# 31                          Москва ТЦ "Семеновский"       31
# 32                       Москва ТЦ "Серебряный Дом"       32
# 33                                Мытищи ТРК "XL-3"       33
# 34                             Н.Новгород ТРЦ "РИО"       34
# 35                      Н.Новгород ТРЦ "Фантастика"       35
# 36            Новосибирск ТРЦ "Галерея Новосибирск"       36
# 37                            Новосибирск ТЦ "Мега"       37
# 38                                   Омск ТЦ "Мега"       38
# 39            РостовНаДону ТРК "Мегацентр Горизонт"       39
# 40  РостовНаДону ТРК "Мегацентр Горизонт" Островной       40
# 41                           РостовНаДону ТЦ "Мега"       41
# 42                           СПб ТК "Невский Центр"       42
# 43                                  СПб ТК "Сенная"       43
# 44                              Самара ТЦ "Мелодия"       44
# 45                             Самара ТЦ "ПаркХаус"       45
# 46                            Сергиев Посад ТЦ "7Я"       46
# 47                           Сургут ТРЦ "Сити Молл"       47
# 48                     Томск ТРЦ "Изумрудный Город"       48
# 49                            Тюмень ТРЦ "Кристалл"       49
# 50                               Тюмень ТЦ "Гудвин"       50
# 51                        Тюмень ТЦ "Зеленый Берег"       51
# 52                             Уфа ТК "Центральный"       52
# 53                                 Уфа ТЦ "Семья" 2       53
# 54                                  Химки ТЦ "Мега"       54
# 55                         Цифровой склад 1С-Онлайн       55
# 56                             Чехов ТРЦ "Карнавал"       56
# 57                          Якутск Орджоникидзе, 56       57
# 58                          Якутск ТЦ "Центральный"       58
# 59                           Ярославль ТЦ "Альтаир"       59

# %%
train.drop(['date'], inplace = True , axis = 1)

# %%
train = train.groupby([c for c in train.columns if c not in ['item_cnt_day'] ], as_index = False)['item_cnt_day'].sum()
train
# Out:
#          date_block_num  shop_id  item_id  item_price  year  month  \
# 0                     0        0       32       221.0  2013      1
# 1                     0        0       33       347.0  2013      1
# 2                     0        0       35       247.0  2013      1
# 3                     0        0       43       221.0  2013      1
# 4                     0        0       51       127.0  2013      1
# ...                 ...      ...      ...         ...   ...    ...
# 1739017              33       59    22087       119.0  2015     10
# 1739018              33       59    22088       119.0  2015     10
# 1739019              33       59    22091       179.0  2015     10
# 1739020              33       59    22100       629.0  2015     10
# 1739021              33       59    22102      1250.0  2015     10
#
#          item_cnt_day
# 0                 6.0
# 1                 3.0
# 2                 1.0
# 3                 1.0
# 4                 1.0
# ...               ...
# 1739017           6.0
# 1739018           2.0
# 1739019           1.0
# 1739020           1.0
# 1739021           1.0
#
# [1739022 rows x 7 columns]

# %%
train = train.rename(columns = {'item_cnt_day' : 'item_cnt_month'})

# %%
train
# Out:
#          date_block_num  shop_id  item_id  item_price  year  month  \
# 0                     0        0       32       221.0  2013      1
# 1                     0        0       33       347.0  2013      1
# 2                     0        0       35       247.0  2013      1
# 3                     0        0       43       221.0  2013      1
# 4                     0        0       51       127.0  2013      1
# ...                 ...      ...      ...         ...   ...    ...
# 1739017              33       59    22087       119.0  2015     10
# 1739018              33       59    22088       119.0  2015     10
# 1739019              33       59    22091       179.0  2015     10
# 1739020              33       59    22100       629.0  2015     10
# 1739021              33       59    22102      1250.0  2015     10
#
#          item_cnt_month
# 0                   6.0
# 1                   3.0
# 2                   1.0
# 3                   1.0
# 4                   1.0
# ...                 ...
# 1739017             6.0
# 1739018             2.0
# 1739019             1.0
# 1739020             1.0
# 1739021             1.0
#
# [1739022 rows x 7 columns]

# %% [markdown]
# items

# %%
categories
# Out:
#            item_category_name  item_category_id
# 0     PC - Гарнитуры/Наушники                 0
# 1            Аксессуары - PS2                 1
# 2            Аксессуары - PS3                 2
# 3            Аксессуары - PS4                 3
# 4            Аксессуары - PSP                 4
# ..                        ...               ...
# 79                  Служебные                79
# 80         Служебные - Билеты                80
# 81    Чистые носители (шпиль)                81
# 82  Чистые носители (штучные)                82
# 83           Элементы питания                83
#
# [84 rows x 2 columns]

# %%
## mean of sales per product per shop
train_mean_month = train [['shop_id','item_id','item_cnt_month']].groupby(['shop_id','item_id'], as_index=False)[['item_cnt_month']].mean()

# %%
train_mean_month= train_mean_month.rename(columns = {'item_cnt_month' : 'item_mean_month'})
train
# Out:
#          date_block_num  shop_id  item_id  item_price  year  month  \
# 0                     0        0       32       221.0  2013      1
# 1                     0        0       33       347.0  2013      1
# 2                     0        0       35       247.0  2013      1
# 3                     0        0       43       221.0  2013      1
# 4                     0        0       51       127.0  2013      1
# ...                 ...      ...      ...         ...   ...    ...
# 1739017              33       59    22087       119.0  2015     10
# 1739018              33       59    22088       119.0  2015     10
# 1739019              33       59    22091       179.0  2015     10
# 1739020              33       59    22100       629.0  2015     10
# 1739021              33       59    22102      1250.0  2015     10
#
#          item_cnt_month
# 0                   6.0
# 1                   3.0
# 2                   1.0
# 3                   1.0
# 4                   1.0
# ...                 ...
# 1739017             6.0
# 1739018             2.0
# 1739019             1.0
# 1739020             1.0
# 1739021             1.0
#
# [1739022 rows x 7 columns]

# %%
train= pd.merge(train , train_mean_month , how = 'left' ,on = ['shop_id' ,'item_id'] )

# %%
train
# Out:
#          date_block_num  shop_id  item_id  item_price  year  month  \
# 0                     0        0       32       221.0  2013      1
# 1                     0        0       33       347.0  2013      1
# 2                     0        0       35       247.0  2013      1
# 3                     0        0       43       221.0  2013      1
# 4                     0        0       51       127.0  2013      1
# ...                 ...      ...      ...         ...   ...    ...
# 1739017              33       59    22087       119.0  2015     10
# 1739018              33       59    22088       119.0  2015     10
# 1739019              33       59    22091       179.0  2015     10
# 1739020              33       59    22100       629.0  2015     10
# 1739021              33       59    22102      1250.0  2015     10
#
#          item_cnt_month  item_mean_month
# 0                   6.0         8.000000
# 1                   3.0         3.000000
# 2                   1.0         7.500000
# 3                   1.0         1.000000
# 4                   1.0         1.666667
# ...                 ...              ...
# 1739017             6.0         6.235294
# 1739018             2.0         6.000000
# 1739019             1.0         2.294118
# 1739020             1.0         1.000000
# 1739021             1.0         1.333333
#
# [1739022 rows x 8 columns]

# %%
shop_prev_month = train [train['date_block_num'] == 33 ]  [['shop_id' ,'item_id' ,'item_cnt_month'] ]
shop_prev_month = shop_prev_month.rename(columns = {'item_cnt_month' : 'item_cnt_prev_month'})

# %%
s= train [train['date_block_num'] == 33 ].groupby(['shop_id' ,'item_id'] , as_index=False)['item_cnt_month'].sum()

# %%
s = s.rename(columns = {'item_cnt_month' : 'item_cnt_prev_month'})

# %%
shop_prev_month
# Out:
#          shop_id  item_id  item_cnt_prev_month
# 1705824        2       31                  1.0
# 1705825        2      486                  3.0
# 1705826        2      787                  1.0
# 1705827        2      794                  1.0
# 1705828        2      968                  1.0
# ...          ...      ...                  ...
# 1739017       59    22087                  6.0
# 1739018       59    22088                  2.0
# 1739019       59    22091                  1.0
# 1739020       59    22100                  1.0
# 1739021       59    22102                  1.0
#
# [33198 rows x 3 columns]

# %%
train= pd.merge(train , shop_prev_month , how = 'left' ,on = ['shop_id' ,'item_id'] )

# %%
train = train.fillna(0.)

# %%
train
# Out:
#          date_block_num  shop_id  item_id  item_price  year  month  \
# 0                     0        0       32       221.0  2013      1
# 1                     0        0       33       347.0  2013      1
# 2                     0        0       35       247.0  2013      1
# 3                     0        0       43       221.0  2013      1
# 4                     0        0       51       127.0  2013      1
# ...                 ...      ...      ...         ...   ...    ...
# 1832201              33       59    22087       119.0  2015     10
# 1832202              33       59    22088       119.0  2015     10
# 1832203              33       59    22091       179.0  2015     10
# 1832204              33       59    22100       629.0  2015     10
# 1832205              33       59    22102      1250.0  2015     10
#
#          item_cnt_month  item_mean_month  item_cnt_prev_month
# 0                   6.0         8.000000                  0.0
# 1                   3.0         3.000000                  0.0
# 2                   1.0         7.500000                  0.0
# 3                   1.0         1.000000                  0.0
# 4                   1.0         1.666667                  0.0
# ...                 ...              ...                  ...
# 1832201             6.0         6.235294                  6.0
# 1832202             2.0         6.000000                  2.0
# 1832203             1.0         2.294118                  1.0
# 1832204             1.0         1.000000                  1.0
# 1832205             1.0         1.333333                  1.0
#
# [1832206 rows x 9 columns]

# %%
## Adding now all the features : 
train =  pd.merge (train ,  items , how  = 'left',on = ['item_id'])

# %%
train =  pd.merge (train ,  categories , how  = 'left',on = ['item_category_id'])

# %%
train =  pd.merge (train ,  shops , how  = 'left',on = ['shop_id'])

# %%
train
# Out:
#          date_block_num  shop_id  item_id  item_price  year  month  \
# 0                     0        0       32       221.0  2013      1
# 1                     0        0       33       347.0  2013      1
# 2                     0        0       35       247.0  2013      1
# 3                     0        0       43       221.0  2013      1
# 4                     0        0       51       127.0  2013      1
# ...                 ...      ...      ...         ...   ...    ...
# 1832201              33       59    22087       119.0  2015     10
# 1832202              33       59    22088       119.0  2015     10
# 1832203              33       59    22091       179.0  2015     10
# 1832204              33       59    22100       629.0  2015     10
# 1832205              33       59    22102      1250.0  2015     10
#
#          item_cnt_month  item_mean_month  item_cnt_prev_month  \
# 0                   6.0         8.000000                  0.0
# 1                   3.0         3.000000                  0.0
# 2                   1.0         7.500000                  0.0
# 3                   1.0         1.000000                  0.0
# 4                   1.0         1.666667                  0.0
# ...                 ...              ...                  ...
# 1832201             6.0         6.235294                  6.0
# 1832202             2.0         6.000000                  2.0
# 1832203             1.0         2.294118                  1.0
# 1832204             1.0         1.000000                  1.0
# 1832205             1.0         1.333333                  1.0
#
#                                                  item_name  item_category_id  \
# 0                                                      1+1                40
# 1                                                 1+1 (BD)                37
# 2                                            10 ЛЕТ СПУСТЯ                40
# 3                                       100 МИЛЛИОНОВ ЕВРО                40
# 4        100 лучших произведений классики (mp3-CD) (Dig...                57
# ...                                                    ...               ...
# 1832201                  Элемент питания DURACELL LR03-BC2                83
# 1832202                  Элемент питания DURACELL LR06-BC2                83
# 1832203          Элемент питания DURACELL TURBO LR 03 2*BL                83
# 1832204                        Энциклопедия Adventure Time                42
# 1832205                          Энциклопедия Мир Ведьмака                42
#
#                     item_category_name                      shop_name
# 0                           Кино - DVD  !Якутск Орджоникидзе, 56 фран
# 1                       Кино - Blu-Ray  !Якутск Орджоникидзе, 56 фран
# 2                           Кино - DVD  !Якутск Орджоникидзе, 56 фран
# 3                           Кино - DVD  !Якутск Орджоникидзе, 56 фран
# 4                         Музыка - MP3  !Якутск Орджоникидзе, 56 фран
# ...                                ...                            ...
# 1832201               Элементы питания         Ярославль ТЦ "Альтаир"
# 1832202               Элементы питания         Ярославль ТЦ "Альтаир"
# 1832203               Элементы питания         Ярославль ТЦ "Альтаир"
# 1832204  Книги - Артбуки, энциклопедии         Ярославль ТЦ "Альтаир"
# 1832205  Книги - Артбуки, энциклопедии         Ярославль ТЦ "Альтаир"
#
# [1832206 rows x 13 columns]

# %%
test['month'] = 11

# %%
test
# Out:
#             ID  shop_id  item_id  month
# 0            0        5     5037     11
# 1            1        5     5320     11
# 2            2        5     5233     11
# 3            3        5     5232     11
# 4            4        5     5268     11
# ...        ...      ...      ...    ...
# 214195  214195       45    18454     11
# 214196  214196       45    16188     11
# 214197  214197       45    15757     11
# 214198  214198       45    19648     11
# 214199  214199       45      969     11
#
# [214200 rows x 4 columns]

# %%
test = pd.merge (test ,  items , how  = 'left',on = ['item_id'])

# %%
test =  pd.merge (test,  categories , how  = 'left',on = ['item_category_id'])
test.shape
# Out:
# (214200, 7)

# %%
test = pd.merge ( test,  shops , how  = 'left',on = ['shop_id'])

# %%
test.shape
# Out:
# (214200, 8)

# %%
test['year'] = 2015

# %%
test
# Out:
#             ID  shop_id  item_id  month  \
# 0            0        5     5037     11
# 1            1        5     5320     11
# 2            2        5     5233     11
# 3            3        5     5232     11
# 4            4        5     5268     11
# ...        ...      ...      ...    ...
# 214195  214195       45    18454     11
# 214196  214196       45    16188     11
# 214197  214197       45    15757     11
# 214198  214198       45    19648     11
# 214199  214199       45      969     11
#
#                                                 item_name  item_category_id  \
# 0                          NHL 15 [PS3, русские субтитры]                19
# 1                         ONE DIRECTION  Made In The A.M.                55
# 2       Need for Speed Rivals (Essentials) [PS3, русск...                19
# 3       Need for Speed Rivals (Classics) [Xbox 360, ру...                23
# 4                    Need for Speed [PS4, русская версия]                20
# ...                                                   ...               ...
# 214195                                        СБ. Союз 55                55
# 214196                       Настольная игра Нано Кёрлинг                64
# 214197                 НОВИКОВ АЛЕКСАНДР  Новая коллекция                55
# 214198                    ТЕРЕМ - ТЕРЕМОК сб.м/ф (Регион)                40
# 214199                             3 ДНЯ НА УБИЙСТВО (BD)                37
#
#                          item_category_name               shop_name  year
# 0                                Игры - PS3  Вологда ТРЦ "Мармелад"  2015
# 1       Музыка - CD локального производства  Вологда ТРЦ "Мармелад"  2015
# 2                                Игры - PS3  Вологда ТРЦ "Мармелад"  2015
# 3                           Игры - XBOX 360  Вологда ТРЦ "Мармелад"  2015
# 4                                Игры - PS4  Вологда ТРЦ "Мармелад"  2015
# ...                                     ...                     ...   ...
# 214195  Музыка - CD локального производства    Самара ТЦ "ПаркХаус"  2015
# 214196            Подарки - Настольные игры    Самара ТЦ "ПаркХаус"  2015
# 214197  Музыка - CD локального производства    Самара ТЦ "ПаркХаус"  2015
# 214198                           Кино - DVD    Самара ТЦ "ПаркХаус"  2015
# 214199                       Кино - Blu-Ray    Самара ТЦ "ПаркХаус"  2015
#
# [214200 rows x 9 columns]

# %%
 test ['date_block_num'] = 34

# %%
test
# Out:
#             ID  shop_id  item_id  month  \
# 0            0        5     5037     11
# 1            1        5     5320     11
# 2            2        5     5233     11
# 3            3        5     5232     11
# 4            4        5     5268     11
# ...        ...      ...      ...    ...
# 214195  214195       45    18454     11
# 214196  214196       45    16188     11
# 214197  214197       45    15757     11
# 214198  214198       45    19648     11
# 214199  214199       45      969     11
#
#                                                 item_name  item_category_id  \
# 0                          NHL 15 [PS3, русские субтитры]                19
# 1                         ONE DIRECTION  Made In The A.M.                55
# 2       Need for Speed Rivals (Essentials) [PS3, русск...                19
# 3       Need for Speed Rivals (Classics) [Xbox 360, ру...                23
# 4                    Need for Speed [PS4, русская версия]                20
# ...                                                   ...               ...
# 214195                                        СБ. Союз 55                55
# 214196                       Настольная игра Нано Кёрлинг                64
# 214197                 НОВИКОВ АЛЕКСАНДР  Новая коллекция                55
# 214198                    ТЕРЕМ - ТЕРЕМОК сб.м/ф (Регион)                40
# 214199                             3 ДНЯ НА УБИЙСТВО (BD)                37
#
#                          item_category_name               shop_name  year  \
# 0                                Игры - PS3  Вологда ТРЦ "Мармелад"  2015
# 1       Музыка - CD локального производства  Вологда ТРЦ "Мармелад"  2015
# 2                                Игры - PS3  Вологда ТРЦ "Мармелад"  2015
# 3                           Игры - XBOX 360  Вологда ТРЦ "Мармелад"  2015
# 4                                Игры - PS4  Вологда ТРЦ "Мармелад"  2015
# ...                                     ...                     ...   ...
# 214195  Музыка - CD локального производства    Самара ТЦ "ПаркХаус"  2015
# 214196            Подарки - Настольные игры    Самара ТЦ "ПаркХаус"  2015
# 214197  Музыка - CD локального производства    Самара ТЦ "ПаркХаус"  2015
# 214198                           Кино - DVD    Самара ТЦ "ПаркХаус"  2015
# 214199                       Кино - Blu-Ray    Самара ТЦ "ПаркХаус"  2015
#
#         date_block_num
# 0                   34
# 1                   34
# 2                   34
# 3                   34
# 4                   34
# ...                ...
# 214195              34
# 214196              34
# 214197              34
# 214198              34
# 214199              34
#
# [214200 rows x 10 columns]

# %%
test= pd.merge(test, s , how = 'left' ,on = ['shop_id' ,'item_id'] )
test
# Out:
#             ID  shop_id  item_id  month  \
# 0            0        5     5037     11
# 1            1        5     5320     11
# 2            2        5     5233     11
# 3            3        5     5232     11
# 4            4        5     5268     11
# ...        ...      ...      ...    ...
# 214195  214195       45    18454     11
# 214196  214196       45    16188     11
# 214197  214197       45    15757     11
# 214198  214198       45    19648     11
# 214199  214199       45      969     11
#
#                                                 item_name  item_category_id  \
# 0                          NHL 15 [PS3, русские субтитры]                19
# 1                         ONE DIRECTION  Made In The A.M.                55
# 2       Need for Speed Rivals (Essentials) [PS3, русск...                19
# 3       Need for Speed Rivals (Classics) [Xbox 360, ру...                23
# 4                    Need for Speed [PS4, русская версия]                20
# ...                                                   ...               ...
# 214195                                        СБ. Союз 55                55
# 214196                       Настольная игра Нано Кёрлинг                64
# 214197                 НОВИКОВ АЛЕКСАНДР  Новая коллекция                55
# 214198                    ТЕРЕМ - ТЕРЕМОК сб.м/ф (Регион)                40
# 214199                             3 ДНЯ НА УБИЙСТВО (BD)                37
#
#                          item_category_name               shop_name  year  \
# 0                                Игры - PS3  Вологда ТРЦ "Мармелад"  2015
# 1       Музыка - CD локального производства  Вологда ТРЦ "Мармелад"  2015
# 2                                Игры - PS3  Вологда ТРЦ "Мармелад"  2015
# 3                           Игры - XBOX 360  Вологда ТРЦ "Мармелад"  2015
# 4                                Игры - PS4  Вологда ТРЦ "Мармелад"  2015
# ...                                     ...                     ...   ...
# 214195  Музыка - CD локального производства    Самара ТЦ "ПаркХаус"  2015
# 214196            Подарки - Настольные игры    Самара ТЦ "ПаркХаус"  2015
# 214197  Музыка - CD локального производства    Самара ТЦ "ПаркХаус"  2015
# 214198                           Кино - DVD    Самара ТЦ "ПаркХаус"  2015
# 214199                       Кино - Blu-Ray    Самара ТЦ "ПаркХаус"  2015
#
#         date_block_num  item_cnt_prev_month
# 0                   34                  NaN
# 1                   34                  NaN
# 2                   34                  1.0
# 3                   34                  NaN
# 4                   34                  NaN
# ...                ...                  ...
# 214195              34                  1.0
# 214196              34                  NaN
# 214197              34                  NaN
# 214198              34                  NaN
# 214199              34                  NaN
#
# [214200 rows x 11 columns]

# %%
test.ID[5]
# Out:
# 5

# %%
#test= pd.merge(test, shop_prev_month , how = 'left' ,on = ['shop_id' ,'item_id'] )
#test.shape
# Out:
# (215803, 11)

# %%
test= pd.merge(test , train_mean_month , how = 'left' ,on = ['shop_id' ,'item_id'] )

# %%
test = test.fillna(0.)

# %%
test
# Out:
#             ID  shop_id  item_id  month  \
# 0            0        5     5037     11
# 1            1        5     5320     11
# 2            2        5     5233     11
# 3            3        5     5232     11
# 4            4        5     5268     11
# ...        ...      ...      ...    ...
# 214195  214195       45    18454     11
# 214196  214196       45    16188     11
# 214197  214197       45    15757     11
# 214198  214198       45    19648     11
# 214199  214199       45      969     11
#
#                                                 item_name  item_category_id  \
# 0                          NHL 15 [PS3, русские субтитры]                19
# 1                         ONE DIRECTION  Made In The A.M.                55
# 2       Need for Speed Rivals (Essentials) [PS3, русск...                19
# 3       Need for Speed Rivals (Classics) [Xbox 360, ру...                23
# 4                    Need for Speed [PS4, русская версия]                20
# ...                                                   ...               ...
# 214195                                        СБ. Союз 55                55
# 214196                       Настольная игра Нано Кёрлинг                64
# 214197                 НОВИКОВ АЛЕКСАНДР  Новая коллекция                55
# 214198                    ТЕРЕМ - ТЕРЕМОК сб.м/ф (Регион)                40
# 214199                             3 ДНЯ НА УБИЙСТВО (BD)                37
#
#                          item_category_name               shop_name  year  \
# 0                                Игры - PS3  Вологда ТРЦ "Мармелад"  2015
# 1       Музыка - CD локального производства  Вологда ТРЦ "Мармелад"  2015
# 2                                Игры - PS3  Вологда ТРЦ "Мармелад"  2015
# 3                           Игры - XBOX 360  Вологда ТРЦ "Мармелад"  2015
# 4                                Игры - PS4  Вологда ТРЦ "Мармелад"  2015
# ...                                     ...                     ...   ...
# 214195  Музыка - CD локального производства    Самара ТЦ "ПаркХаус"  2015
# 214196            Подарки - Настольные игры    Самара ТЦ "ПаркХаус"  2015
# 214197  Музыка - CD локального производства    Самара ТЦ "ПаркХаус"  2015
# 214198                           Кино - DVD    Самара ТЦ "ПаркХаус"  2015
# 214199                       Кино - Blu-Ray    Самара ТЦ "ПаркХаус"  2015
#
#         date_block_num  item_cnt_prev_month  item_mean_month
# 0                   34                  0.0         1.181818
# 1                   34                  0.0         0.000000
# 2                   34                  1.0         1.428571
# 3                   34                  0.0         1.000000
# 4                   34                  0.0         0.000000
# ...                ...                  ...              ...
# 214195              34                  1.0         1.800000
# 214196              34                  0.0         0.000000
# 214197              34                  0.0         1.166667
# 214198              34                  0.0         0.000000
# 214199              34                  0.0         1.666667
#
# [214200 rows x 12 columns]

# %%
test['item_cnt_month'] = 0.

# %%
from sklearn import preprocessing
for c in ['item_name' , 'item_category_name' , 'shop_name'] :
    e = preprocessing.LabelEncoder()
    e.fit(list(train[c].unique()) + list(test[c].unique()))
    train[c] = e.transform(train[c].astype(str))
    test[c] = e.transform(test[c].astype(str))
    print(c)
# Out:
# item_name
# item_category_name
# shop_name

# %%
test.fillna(0.)
# Out:
#             ID  shop_id  item_id  month  item_name  item_category_id  \
# 0            0        5     5037     11       5037                19
# 1            1        5     5320     11       5320                55
# 2            2        5     5233     11       5233                19
# 3            3        5     5232     11       5232                23
# 4            4        5     5268     11       5268                20
# ...        ...      ...      ...    ...        ...               ...
# 214195  214195       45    18454     11      18454                55
# 214196  214196       45    16188     11      16188                64
# 214197  214197       45    15757     11      15757                55
# 214198  214198       45    19648     11      19648                40
# 214199  214199       45      969     11        969                37
#
#         item_category_name  shop_name  year  date_block_num  \
# 0                       19          5  2015              34
# 1                       55          5  2015              34
# 2                       19          5  2015              34
# 3                       23          5  2015              34
# 4                       20          5  2015              34
# ...                    ...        ...   ...             ...
# 214195                  55         45  2015              34
# 214196                  64         45  2015              34
# 214197                  55         45  2015              34
# 214198                  40         45  2015              34
# 214199                  37         45  2015              34
#
#         item_cnt_prev_month  item_mean_month
# 0                       0.0         1.181818
# 1                       0.0         0.000000
# 2                       1.0         1.428571
# 3                       0.0         1.000000
# 4                       0.0         0.000000
# ...                     ...              ...
# 214195                  1.0         1.800000
# 214196                  0.0         0.000000
# 214197                  0.0         1.166667
# 214198                  0.0         0.000000
# 214199                  0.0         1.666667
#
# [214200 rows x 12 columns]

# %%
train ['item_cnt_month']
# Out:
# 0          6.0
# 1          3.0
# 2          1.0
# 3          1.0
# 4          1.0
#           ...
# 1832201    6.0
# 1832202    2.0
# 1832203    1.0
# 1832204    1.0
# 1832205    1.0
# Name: item_cnt_month, Length: 1832206, dtype: float64

# %%
train.drop(['item_price'] ,axis = 1 , inplace = True)

# %%
train
# Out:
#          date_block_num  shop_id  item_id  year  month  item_cnt_month  \
# 0                     0        0       32  2013      1             6.0
# 1                     0        0       33  2013      1             3.0
# 2                     0        0       35  2013      1             1.0
# 3                     0        0       43  2013      1             1.0
# 4                     0        0       51  2013      1             1.0
# ...                 ...      ...      ...   ...    ...             ...
# 1832201              33       59    22087  2015     10             6.0
# 1832202              33       59    22088  2015     10             2.0
# 1832203              33       59    22091  2015     10             1.0
# 1832204              33       59    22100  2015     10             1.0
# 1832205              33       59    22102  2015     10             1.0
#
#          item_mean_month  item_cnt_prev_month  item_name  item_category_id  \
# 0               8.000000                  0.0         32                40
# 1               3.000000                  0.0         33                37
# 2               7.500000                  0.0         35                40
# 3               1.000000                  0.0         43                40
# 4               1.666667                  0.0         51                57
# ...                  ...                  ...        ...               ...
# 1832201         6.235294                  6.0      22087                83
# 1832202         6.000000                  2.0      22088                83
# 1832203         2.294118                  1.0      22091                83
# 1832204         1.000000                  1.0      22100                42
# 1832205         1.333333                  1.0      22102                42
#
#          item_category_name  shop_name
# 0                        40          0
# 1                        37          0
# 2                        40          0
# 3                        40          0
# 4                        57          0
# ...                     ...        ...
# 1832201                  83         59
# 1832202                  83         59
# 1832203                  83         59
# 1832204                  42         59
# 1832205                  42         59
#
# [1832206 rows x 12 columns]

# %%
test
# Out:
#             ID  shop_id  item_id  month  item_name  item_category_id  \
# 0            0        5     5037     11       5037                19
# 1            1        5     5320     11       5320                55
# 2            2        5     5233     11       5233                19
# 3            3        5     5232     11       5232                23
# 4            4        5     5268     11       5268                20
# ...        ...      ...      ...    ...        ...               ...
# 214195  214195       45    18454     11      18454                55
# 214196  214196       45    16188     11      16188                64
# 214197  214197       45    15757     11      15757                55
# 214198  214198       45    19648     11      19648                40
# 214199  214199       45      969     11        969                37
#
#         item_category_name  shop_name  year  date_block_num  \
# 0                       19          5  2015              34
# 1                       55          5  2015              34
# 2                       19          5  2015              34
# 3                       23          5  2015              34
# 4                       20          5  2015              34
# ...                    ...        ...   ...             ...
# 214195                  55         45  2015              34
# 214196                  64         45  2015              34
# 214197                  55         45  2015              34
# 214198                  40         45  2015              34
# 214199                  37         45  2015              34
#
#         item_cnt_prev_month  item_mean_month
# 0                       0.0         1.181818
# 1                       0.0         0.000000
# 2                       1.0         1.428571
# 3                       0.0         1.000000
# 4                       0.0         0.000000
# ...                     ...              ...
# 214195                  1.0         1.800000
# 214196                  0.0         0.000000
# 214197                  0.0         1.166667
# 214198                  0.0         0.000000
# 214199                  0.0         1.666667
#
# [214200 rows x 12 columns]

# %%
from sklearn.model_selection import cross_val_score, GridSearchCV
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import MinMaxScaler

# %%
from sklearn.model_selection import train_test_split
X_train = train [train['date_block_num']<33]
y_train = np.log1p(train [train['date_block_num']<33] ['item_cnt_month'].clip(0. , 20.))
X_test = train [train['date_block_num']==33]
y_test = np.log1p(X_test['item_cnt_month'].clip(0. , 20.))

# %%
y_test.shape
# Out:
# (40412,)

# %%
X_test.shape
# Out:
# (40412, 12)

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
test
# Out:
#             ID  shop_id  item_id  month  item_name  item_category_id  \
# 0            0        5     5037     11       5037                19
# 1            1        5     5320     11       5320                55
# 2            2        5     5233     11       5233                19
# 3            3        5     5232     11       5232                23
# 4            4        5     5268     11       5268                20
# ...        ...      ...      ...    ...        ...               ...
# 214195  214195       45    18454     11      18454                55
# 214196  214196       45    16188     11      16188                64
# 214197  214197       45    15757     11      15757                55
# 214198  214198       45    19648     11      19648                40
# 214199  214199       45      969     11        969                37
#
#         item_category_name  shop_name  year  date_block_num  \
# 0                       19          5  2015              34
# 1                       55          5  2015              34
# 2                       19          5  2015              34
# 3                       23          5  2015              34
# 4                       20          5  2015              34
# ...                    ...        ...   ...             ...
# 214195                  55         45  2015              34
# 214196                  64         45  2015              34
# 214197                  55         45  2015              34
# 214198                  40         45  2015              34
# 214199                  37         45  2015              34
#
#         item_cnt_prev_month  item_mean_month
# 0                       0.0         1.181818
# 1                       0.0         0.000000
# 2                       1.0         1.428571
# 3                       0.0         1.000000
# 4                       0.0         0.000000
# ...                     ...              ...
# 214195                  1.0         1.800000
# 214196                  0.0         0.000000
# 214197                  0.0         1.166667
# 214198                  0.0         0.000000
# 214199                  0.0         1.666667
#
# [214200 rows x 12 columns]

# %%
X_test.drop(['item_cnt_month'] , inplace = True , axis = 1)
# Out:
# E:\Systems\lib\site-packages\pandas\core\frame.py:4102: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
X_train.drop(['item_cnt_month'] , inplace = True , axis = 1)

# %%
 regr = RandomForestRegressor(n_estimators=50 , criterion='mse', max_depth=15 , min_samples_split=2,
                              bootstrap=True, oob_score=False, n_jobs=-1,random_state=18 ,
                              verbose=0, warm_start=False)

# %%
regr.fit(X_train , y_train)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=15,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=50, n_jobs=-1,
#                       oob_score=False, random_state=18, verbose=0,
#                       warm_start=False)

# %%
regr.feature_importances_
# Out:
# array([0.03778056, 0.00902609, 0.02524506, 0.01709312, 0.02440284,
#        0.80277471, 0.01718154, 0.02512691, 0.01622195, 0.0161651 ,
#        0.0089821 ])

# %%
preds = regr.predict(X_test)

# %%
y_test
# Out:
# 1791794    0.693147
# 1791795    1.386294
# 1791796    0.693147
# 1791797    0.693147
# 1791798    0.693147
#              ...
# 1832201    1.945910
# 1832202    1.098612
# 1832203    0.693147
# 1832204    0.693147
# 1832205    0.693147
# Name: item_cnt_month, Length: 40412, dtype: float64

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y_test, preds)
# Out:
# 0.10412745075551531

# %%
test2.shape
# Out:
# (214200, 3)

# %%
test.drop(['item_cnt_month'] , inplace = True , axis = 1)

# %%
test.shape
# Out:
# (215803, 12)

# %%
test2 = pd.read_csv('E:/personal_projects/competitive-data-science-predict-future-sales/test.csv')
test2.shape
# Out:
# (214200, 3)

# %%
test2 = pd.read_csv('E:/personal_projects/competitive-data-science-predict-future-sales/test.csv')
submission2 = pd.DataFrame()
submission2['ID'] = test2.ID
submission2['item_cnt_month'] = regr.predict(test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-170-982eb45a07dc> in <module>
#       2 submission2 = pd.DataFrame()
#       3 submission2['ID'] = test2.ID
# ----> 4 submission2['item_cnt_month'] = regr.predict(test)
#
# E:\Systems\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3470         else:
#    3471             # set column
# -> 3472             self._set_item(key, value)
#    3473
#    3474     def _setitem_slice(self, key, value):
#
# E:\Systems\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3547
#    3548         self._ensure_valid_index(value)
# -> 3549         value = self._sanitize_column(key, value)
#    3550         NDFrame._set_item(self, key, value)
#    3551
#
# E:\Systems\lib\site-packages\pandas\core\frame.py in _sanitize_column(self, key, value, broadcast)
#    3732
#    3733             # turn me into an ndarray
# -> 3734             value = sanitize_index(value, self.index, copy=False)
#    3735             if not isinstance(value, (np.ndarray, Index)):
#    3736                 if isinstance(value, list) and len(value) > 0:
#
# E:\Systems\lib\site-packages\pandas\core\internals\construction.py in sanitize_index(data, index, copy)
#     610
#     611     if len(data) != len(index):
# --> 612         raise ValueError("Length of values does not match length of index")
#     613
#     614     if isinstance(data, ABCIndexClass) and not copy:
#
# ValueError: Length of values does not match length of index

# %%
.
